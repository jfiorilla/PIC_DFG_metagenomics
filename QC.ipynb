# %% [markdown]
# ## md5 check
# August 26, 2026
#
# `sbatch` [md5check](bash-scripts/md5check) script, originally from [Brooke](https://github.com/brookewicz/CBC_metagenomics/blob/db0de23907d5382e904fa32af875cc5fb6519d64/all_sctld/sampleinfo/md5check.txt) but with some edits
# - Her code has a double `#!/bin/bash` that threw errors
#
# Saved outputs in project folder*

# %% [markdown]
# ## Conda environment for QC
# September 2, 2026
#
# `seqproc-env`
# - multiqc
# - fastqc
# - trim-galore

# %% [markdown]
# ## MultiQC on raw FastQC files
# September 14, 2026
#
#  /scratch4/workspace/jade_fiorilla_student_uml_edu-rawseqpic/23LVKKLT3/XXXXX/INFO/fastqc/zip
# - Upload [multiqc_config.yaml](multiqc_config.yaml) to interpret file naming
# - Load conda
# - Activate `seqproc-env`
# - Run `multiqc .`
# - Download html report and save in repo
#
# Repeat for remaining folders (10604-10608)

# %% [markdown]
# ## Trim-Galore on raw FastQC files
# September 14, 2026
#
# /scratch4/workspace/jade_fiorilla_student_uml_edu-rawseqpic/23LVKKLT3/XXXXX/trimmed
#
# Nikea's [metagenomic workflow](https://github.com/nikeaulrich/Metagenomics_workflow/blob/fcfd850453887a23301e5d07c220aab7c9972994/0_QC.ipynb)
#
#
#
# ## MultiQC on trimmed FastQC files
# September 15, 2026
